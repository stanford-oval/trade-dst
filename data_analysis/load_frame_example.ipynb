# %%
import json
import importlib  
analyze_data = importlib.import_module("analyze-data")
filename = 'data/train_dials.json'

with open(filename) as fp:
    dialogue_data = json.load(fp)

df = analyze_data.generate_turn_frame(dialogue_data)
df.head()
# Out:
#             dialogue                                        full_belief  \
# SNG01856_0  SNG01856         [hotel-pricerange-cheap, hotel-type-hotel]
# SNG01856_1  SNG01856                                [hotel-parking-yes]
# SNG01856_2  SNG01856  [hotel-book day-tuesday, hotel-book people-6, ...
# SNG01856_3  SNG01856                                [hotel-book stay-2]
# SNG01856_4  SNG01856                                                 []
#
#            full_empty                                         full_slots  \
# SNG01856_0      False                     [hotel-pricerange, hotel-type]
# SNG01856_1      False                                    [hotel-parking]
# SNG01856_2      False  [hotel-book day, hotel-book people, hotel-book...
# SNG01856_3      False                                  [hotel-book stay]
# SNG01856_4       True                                                 []
#
#                                                   step_belief step_empty  \
# ...
